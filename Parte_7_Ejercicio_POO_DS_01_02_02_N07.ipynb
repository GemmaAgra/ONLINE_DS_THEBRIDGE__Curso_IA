# %% [markdown]
# <a href="https://colab.research.google.com/github/GemmaAgra/ONLINE_DS_THEBRIDGE__Curso_IA/blob/main/Parte_7_Ejercicio_POO_DS_01_02_02_N07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![TheBridge_logo_RGB_color.jpg](attachment:TheBridge_logo_RGB_color.jpg)

# %% [markdown]
# ![ejercicios.png](attachment:ejercicios.png)

# %% [markdown]
# # Ejercicios Clases y Objetos

# %% [markdown]
# ## Ejercicio 1
# Somos una empresa que tiene varias tiendas de electrodomesticos. Necesitamos un programa para manejar las tiendas, ver las ventas que han tenido, cuántos empleados hay, etc... Para ello vamos a modelizar la tienda en una clase, que tendrá las siguientes características:
# * Nombre clase: "Tienda"
# * Atributos comunes:
#     * Tipo: "Electrodomésticos"
#     * Abierta: True
# * Atributos propios de cada tienda:
#     * Nombre - String
#     * Dirección - String
#     * Número de empleados - int
#     * Ventas ultimos 3 meses - Lista de 3 numeros
# * Método para calcular las ventas de todos los meses, que devuelva un numero con todas las ventas.
# * Método que calcula la media de ventas de los ultimos meses, por empleado
# * Método que devuelve en un string el nombre de la tienda, junto con su dirección.
# * Método que obtiene las ventas del último mes.
# * Método para dar una proyección de las ventas en caso de haber invertido X dinero en marketing en esa tienda. Siendo X el parámetro de entrada. Si X es menor de 1000, las ventas de los ultimos 3 meses hubiesen sido de (1.2 x ventas), si es mayor o igual de 1000, las ventas hubiesen sido de (1.5 x venta). El método reescribe el atributo de ventas en los últimos 3 meses, y además devuelve las ventas con el aumento.
#
# Se pide:
# 1. Implementar la clase "Tienda"
# 2. Crear tres tiendas con datos inventados
# 3. Comprueba en al menos una de ellas, todo lo implementado en la clase tienda (sus atributos, media de ventas, ventas/empleado...)
# 3. Calcular las ventas del último mes de todas las tiendas. Para ello usa el bucle `for`
# 4. Imprime por pantalla los nombres de las tiendas cuya dirección lleve el string "Avenida"
# 5. Seguro que ya has hecho este apartado... Documenta la clase :)

# %%
class Tienda:
    tipo = "Ropa"
    abierta = True

    # Constructor  Atributos de instancia:
    def __init__(self, nombre, direccion, num_emps, ventas_3_meses):
        self.nombre = nombre
        self.direccion = direccion
        self.num_emps = num_emps
        self.ventas_3_meses = ventas_3_meses


    # metodos 
    # 1. Ventas totales
    def ventas_totales(self):
        return sum(self.ventas_3_meses)

    # 2. Media de ventas/emp
    def media_por_empleado(self):
        return self.ventas_totales() / self.num_emps

    # 3. Nombre + dirección
    def info(self):
        return f"{self.nombre} - {self.direccion}"

    # 4. Ventas último mes
    def ventas_ultimo_mes(self):
        return self.ventas_3_meses[-1]

    # 5. Proyección de ventas con marketing o Ajusta ventas según inversión en marketing
    def proyeccion_marketing(self, x):
        if x < 1000: factor = 1.2
        else:        factor = 1.5

        self.ventas_3_meses = [v * factor for v in self.ventas_3_meses]
        return self.ventas_3_meses
    
tienda1 = Tienda("Tienda 1", "Avda Ppal 10", 5, [1000, 1200, 1500])
tienda2 = Tienda("Tienda 2", "Calle Luna 5", 3, [800, 950, 1100])
tienda3 = Tienda("Tienda 3", "Avda Sol 25", 8, [2000, 2100, 2200])

print("Nombre Tienda: ", tienda1.nombre)
print("Vtas Tot: ", tienda1.ventas_totales())
print("Media por emp: ", tienda1.media_por_empleado())
print("Info: ",tienda1.info())
print("Vtas ultimo mes: ", tienda1.ventas_ultimo_mes())
print("Proyeccion marketing:  ", tienda1.proyeccion_marketing(1500))  # ej. marketing alto

# Vtas del ultimo mes de todas las tiendas
tiendas = [tienda1, tienda2, tienda3]

for t in tiendas:
    print(t.nombre, "->", round(t.ventas_ultimo_mes()))

# Tiendas en Avda
for t in tiendas:
    if "Avda" in t.direccion:
        print(t.nombre)

"""
Clase con atributos de clase + instancia
Métodos con self
Uso de listas para ventas
for para recorrer objetos
Condicionales para lógica de negocio
"""
# Out:
# Nombre Tienda:  Tienda 1
# Vtas Tot:  3700
# Media por emp:  740.0
# Info:  Tienda 1 - Avda Ppal 10
# Vtas ultimo mes:  1500
# Proyeccion marketing:   [1500.0, 1800.0, 2250.0]
# Tienda 1 -> 2250
# Tienda 2 -> 1100
# Tienda 3 -> 2200
# Tienda 1
# Tienda 3
# '\nClase con atributos de clase + instancia\nMétodos con self\nUso de listas para ventas\nfor para recorrer objetos\nCondicionales para lógica de negocio\n'

# %% [markdown]
# ## Ejercicio 2
# En este ejercicio vamos a implementar una clase *Perro* en Python. La clase tiene las siguientes características:
# * Cosas que sabemos seguro que tiene un perro
#     * Tiene 4 patas
#     * 2 orejas
#     * 2 ojos
#     * Una velocidad de 0. Por defecto, el perro está parado
# * Cuando se inicialice:
#     * El perro será de una determinada raza
#     * Por defecto tendrá pelo "Marrón", a no ser que se diga lo contrario.
#     * Por defecto no tendrá dueño, a no ser que se diga lo contrario.
#
# * Dispondrá también de un método llamado andar, que tiene un argumento de entrada (aumento_velocidad). Este valor se le sumará a la velocidad que ya llevaba el perro.
# * Necesita otro método (parar), donde pondremos la velocidad a 0.
# * Otro método llamado "ladrar", que tendrá un argumento de entrada, y la salida será el siguiente string: "GUAU!" + el argumento de entrada.
#
#
# Se pide:
# * Implementa la clase *Perro*
# * Crea un objeto de tipo *Perro*, sin dueño
# * Comprueba que están bien todos sus atributos
# * Prueba que ande, y comprueba su velocidad
# * Páralo
# * Documenta la clase *Perro*

# %%
class Perro:
    # Clase que representa un perro con características y comportamientos (andar, parar y ladrar)
    
    def __init__(self, raza, pelo="Marrón", dueño=None):
        self.patas = 4
        self.orejas = 2
        self.ojos = 2
        self.velocidad = 0     # Estado inicial

        # Atributos de inicialización
        self.raza = raza
        self.pelo = pelo
        self.dueño = dueño

    # Método para aumentar velocidad
    def andar(self, aumento_velocidad):
        self.velocidad += aumento_velocidad

    # Método para parar el perro
    def parar(self):
        self.velocidad = 0

    # Método para ladrar
    def ladrar(self, mensaje):
        return "GUAU! " + mensaje
    
# creo perro sin dueño
mi_perro = Perro(raza="Labrador")

print("Patas:", mi_perro.patas)
print("Orejas:", mi_perro.orejas)
print("Ojos:", mi_perro.ojos)
print("Velocidad:", mi_perro.velocidad)
print("Raza:", mi_perro.raza)
print("Pelo:", mi_perro.pelo)

# anda y veo velocidad
mi_perro.andar(10)
print("Velocidad tras andar: ", mi_perro.velocidad)

#paro al perro
mi_perro.parar()
print("Velocidad tras parar: ", mi_perro.velocidad)

# q ladre
print(mi_perro.ladrar("Estoy feliz"))



#Clase con atributos fijos y dinámicos
#constructor con valores por defecto
#todos que modifican estado (velocidad)
#Método que devuelve string (ladrar)
# Out:
# Patas: 4
# Orejas: 2
# Ojos: 2
# Velocidad: 0
# Raza: Labrador
# Pelo: Marrón
# Velocidad tras andar:  10
# Velocidad tras parar:  0
# GUAU! Estoy feliz
