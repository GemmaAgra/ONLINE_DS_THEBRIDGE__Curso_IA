# %% [markdown]
# ![imagen](./img/ejercicios.png)
#
# # Ejercicios Clases y Objetos

# %% [markdown]
# ## Ejercicio 1
# Somos una empresa que tiene varias tiendas de electrodomésticos. Necesitamos un programa para manejar las tiendas, ver las ventas que han tenido, cuántos empleados hay, etc... Para ello vamos a modelizar la tienda en una clase, que tendrá las siguientes características:
# * Nombre clase: "Tienda"
# * Atributos comunes:
#     * Tipo: "Electrodomésticos"
#     * Abierta: True
# * Atributos propios de cada tienda:
#     * Nombre - String
#     * Dirección - String
#     * Número de empleados - int
#     * Ventas últimos 3 meses - Lista de 3 numeros
# * Método para calcular las ventas de todos los meses, que devuelva un número con todas las ventas.
# * Método que calcula la media de ventas de los últimos meses, por empleado
# * Método que devuelve en un string el nombre de la tienda, junto con su dirección.
# * Método que obtiene las ventas del último mes.
# * Método para dar una proyección de las ventas en caso de haber invertido X dinero en marketing en esa tienda. Siendo X el parámetro de entrada. Si X es menor de 1000, las ventas de los ultimos 3 meses hubiesen sido de (1.2 x ventas), si es mayor o igual de 1000, las ventas hubiesen sido de (1.5 x venta). El método reescribe el atributo de ventas en los últimos 3 meses, y además devuelve las ventas con el aumento.
#
# Se pide:
# 1. Implementar la clase "Tienda"
# 2. Crear tres tiendas con datos inventados
# 3. Comprueba en al menos una de ellas, todo lo implementado en la clase tienda (sus atributos, media de ventas, ventas/empleado...)
# 3. Calcular las ventas del último mes de todas las tiendas. Para ello usa el bucle `for`
# 4. Imprime por pantalla los nombres de las tiendas cuya dirección lleve el string "Avenida"
# 5. Seguro que ya has hecho este apartado... Documenta la clase :)

# %%
class Tienda:   

    # Atributos comunes
    tipo = "Electrodomésticos"
    abierta = True
    
    # Atributos de instancia:
    def __init__(self, nombre, direcc, num_emps, ventas_ultimos_3_meses):
        self.nombre = nombre
        self.direcc = direcc
        self.num_emps = num_emps
        self.ventas_ultimos_3_meses = ventas_ultimos_3_meses

    #   Métodos:
    def total_ventas(self):
        return sum(self.ventas_ultimos_3_meses)

    def media_ventas_por_emp(self):
        if self.num_emps == 0:  return 0
        return self.total_ventas() / self.num_emps

    def info_tienda(self):
        return f"{self.nombre} - {self.direcc}"

    def ventas_ultimo_mes(self):
        return self.ventas_ultimos_3_meses[-1]  # -1 pq ultimo elem de la lista

    def proyeccion_ventas(self, inversion):
        if inversion < 1000: factor = 1.2
        else: factor = 1.5

        self.ventas_ultimos_3_meses = [round(v * factor) for v in self.ventas_ultimos_3_meses]
        return self.ventas_ultimos_3_meses


# 2. Crear 3 tiendas
tienda1 = Tienda("A", "Avda B 10", 5, [100, 120, 110])
tienda2 = Tienda("B", "Calle Mayor 25", 8, [150, 140, 160])
tienda3 = Tienda("C", "Avda A 50", 6, [90, 95, 100])

# 3. Comprobación en una tienda
print("->  Tienda 1 ")
print("Tipo:", tienda1.tipo)
print("Abierta:", tienda1.abierta)
print("Total ventas:", tienda1.total_ventas())
print("Media ventas por emp:", tienda1.media_ventas_por_emp())
print("Info tienda:", tienda1.info_tienda())
print("Ventas último mes:", tienda1.ventas_ultimo_mes())
print("Proyección (500€):", tienda1.proyeccion_ventas(500))

# 4. Ventas del último mes de todas las tiendas
print("\n ->  Ventas último mes ")
tiendas = [tienda1, tienda2, tienda3]
for tienda in tiendas:
    print(tienda.nombre, ":", tienda.ventas_ultimo_mes())

# 5. Tiendas cuya dirección contiene "Avda"
print("\n -> Tiendas en Avda ")
for tienda in tiendas:
    if "Avda" in tienda.direcc:
        print(tienda.nombre)
# Out:
# ->  Tienda 1
# Tipo: Electrodomésticos
# Abierta: True
# Total ventas: 330
# Media ventas por emp: 66.0
# Info tienda: A - Avda B 10
# Ventas último mes: 110
# Proyección (500€): [120, 144, 132]
#
#  ->  Ventas último mes
# A : 132
# B : 160
# C : 100
#
#  -> Tiendas en Avda
# A
# C

# %% [markdown]
# ## Ejercicio 2
# En este ejercicio vamos a implementar una clase *Perro* en Python. La clase tiene las siguientes características:
# * Cosas que sabemos seguro que tiene un perro
#     * Tiene 4 patas
#     * 2 orejas
#     * 2 ojos
#     * Una velocidad de 0. Por defecto, el perro está parado
# * Cuando se inicialice:
#     * El perro será de una determinada raza
#     * Por defecto tendrá pelo "Marrón", a no ser que se diga lo contrario.
#     * Por defecto no tendrá dueño, a no ser que se diga lo contrario.
#
# * Dispondrá también de un método llamado andar, que tiene un argumento de entrada (aumento_velocidad). Este valor se le sumará a la velocidad que ya llevaba el perro.
# * Necesita otro método (parar), donde pondremos la velocidad a 0.
# * Otro método llamado "ladrar", que tendrá un argumento de entrada, y la salida será el siguiente string: "GUAU!" + el argumento de entrada.
#
#
# Se pide:
# * Implementa la clase *Perro*
# * Crea un objeto de tipo *Perro*, sin dueño
# * Comprueba que están bien todos sus atributos
# * Prueba que ande, y comprueba su velocidad
# * Páralo
# * Documenta la clase *Perro*

# %%
class Perro:
   
    # Atributos comunes
    patas = 4
    orejas = 2
    ojos = 2

    # Atributos de instancia
    def __init__(self, raza, color_pelo="Blanco", duenio=None):    # algunos con valores por def.
        self.raza = raza
        self.color_pelo = color_pelo
        self.duenio = duenio
        self.velocidad = 0

    #   Métodos
    def andar(self, aumento_velocidad):
        self.velocidad += aumento_velocidad

    def parar(self):
        self.velocidad = 0

    def ladrar(self, mensaje):
        return "GUAU! " + mensaje


# Crear un perro sin dueño
perro1 = Perro("Golden Retrieve")

# veo atributos
print("Raza: ", perro1.raza)
print("Color: ", perro1.color_pelo)
print("Dueño: ", perro1.duenio)
print("Patas: ", perro1.patas)
print("Orejas: ", perro1.orejas)
print("Ojos: ", perro1.ojos)
print("Velocidad: ", perro1.velocidad)

# q ande
perro1.andar(5)
print("Velocidad tras andar: ", perro1.velocidad)

# q pare
perro1.parar()
print("Velocidad tras parar: ", perro1.velocidad)

# q ladre
print(perro1.ladrar("Hellousss!"))
# Out:
# Raza:  Golden Retrieve
# Color:  Blanco
# Dueño:  None
# Patas:  4
# Orejas:  2
# Ojos:  2
# Velocidad:  0
# Velocidad tras andar:  5
# Velocidad tras parar:  0
# GUAU! Hellousss!
