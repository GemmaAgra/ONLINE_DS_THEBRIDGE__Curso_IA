# %% [markdown]
# <a href="https://colab.research.google.com/github/GemmaAgra/ONLINE_DS_THEBRIDGE__Curso_IA/blob/main/Parte_5_P%C3%ADldora_9_Jupyter_DS_01_02_01_N08_V09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![TheBridge_Python_v0.png](attachment:TheBridge_Python_v0.png)

# %% [markdown]
# ##  Argumentos variables

# %% [markdown]
# ### Contenidos

# %% [markdown]
# * [Introducción  ](#Introducción--)

# %% [markdown]
# ### Introducción
# [al indice](#Contenidos)
# En los ejemplos de la sesión anterior teníamos que fijar un número concreto de argumentos para nuestras funciones, pero hay ocasiones que no tenemos seguro cuántos argumentos son. Por suerte, las funciones de Python nos aportan esa flexibilidad mediante `*`
#
# Veamos cómo implementar una función multiplicadora con numero variable de argumentos

# %%
def multiplicar(*args):
    rdo = 1
    for num in args:
        rdo *= num
    return rdo

# Ej
print(multiplicar(2, 3))
print(multiplicar(2, 3, 4))
print(multiplicar(5, 10, 2, 3))

# otra forma
from functools import reduce
import operator

def multiplicar(*args):
    return reduce(operator.mul, args)
# Out:
# 6
# 24
# 300

# %% [markdown]
# Ten en cuenta que `*args` es algo variable con X elementos. Como no sabemos a priori cuantos son, tendremos que recorrerlos con un `for`, y para cada argumento, aplicarle una operación. Por tanto, `*args` es un iterable, en concreto una **tupla**. Lo que le está dando la funcionalidad de "argumentos variables" es `*`, no `args`. Igual que ponemos `*args`, podemos poner `*argumentos`.
#
# Puedes combinar argumentos posicionales con los `*args`

# %%
# En este ejemplo, uso el ultimo argumento para dividir todo lo que habiamos multiplicado por este argumento
def ejemplo(*args):
    print(args)
    print(type(args))
ejemplo(1, 2, 3, 4)

# El nombre args no importa
def ej(*nums):
    print(nums)
ej(10, 20, 30)

# Recorrer *args con un for
def imprimir(*args):
    for elemento in args:
        print(elemento)
imprimir(5, 10, 15)

# Mezclar args posicionales + *args
def suma(inicio, *args):
    rdo = inicio

    for n in args:
        rdo += n
    return rdo
print(suma(10, 1, 2, 3))

# multiplicación con valor inicial
def multiplicar(inicio, *args):
    rdo = inicio

    for n in args:
        rdo *= n
    return rdo
print(multiplicar(2, 3, 4))
# Out:
# (1, 2, 3, 4)
# <class 'tuple'>
# (10, 20, 30)
# 5
# 10
# 15
# 16
# 24

# %% [markdown]
# <table align="left">
#  <tr>
#      <td style="text-align:left">
#          <h3>ERRORES con argumentos variables</h3>
#
#  </td></tr>
# </table>

# %% [markdown]
# Declara los argumentos variables al principio, y los fijos al final para evitar errores. Además, si los combinas, tendrás que concretar cuáles son los argumentos fijos

# %%
# args variables al ppio (ERROR)
def funcion(*args, x):
    print(args, x)

# ERROR al usarla
funcion(1, 2, 3, 10)   #Python no sabe qué parte va a *args y cuál a x.

# Args fijos después de *args mal usados
def suma(*args, inicio):
    pass
# inicio nunca se puede asignar correctamente por posición, obliga a usar keyword

# Mezclar sin especificar args fijos
def funcion(*args, x, y):
    print(args, x, y)
funcion(1, 2, 3, 4)   # Python no sabe qué son x e y

# Olvidar usar keyword en args fijos tras *args
def funcion(*args, x):
    print(args, x)
funcion(1, 2, 3, 4)    # Error
funcion(1, 2, 3, x=4)  # ok


# CORRECTA (REGLA CLAVE)
def funcion(a, b, *args):
    print(a, b, "y ", args)    
funcion(1, 2, 3, 4, 5)

def funcion(posicionales, *args, keyword_only)   # ok

# mal orden: *args antes de posicionales y mezclar sin indicar keywords
# CLAVE: *args siempre va en el medio o al final y Los args después de *args obligan a usar keyword
